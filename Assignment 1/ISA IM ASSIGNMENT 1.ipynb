# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import math

# %%
# For n = 7 which is the number of elements in our array

# %%
mylist =[0.5,1,1.5,2,2.5,3,3.5]

# %%
x = np.array(mylist)

# %%
x
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5])

# %%
# For Logarithmic = 𝜭((log n) plot
y1 = np.array([math.log(i,2) for i in x])

# %%
y1
# Out:
# array([-1.        ,  0.        ,  0.5849625 ,  1.        ,  1.32192809,
#         1.5849625 ,  1.80735492])

# %%
# For Linear = 𝜭(n) plot
y2 = x

# %%
y2
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5])

# %%
# For Quadratic = 𝜭(n**2) plot
y3 = x**2

# %%
y3
# Out:
# array([ 0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25])

# %%
# For Cubic = 𝜭(n**3) plot
y4 = x**3

# %%
y4
# Out:
# array([ 0.125,  1.   ,  3.375,  8.   , 15.625, 27.   , 42.875])

# %%
# For Polynomial = 𝜭(n**k) plot where k = 4
k=4
y5 = x**k

# %%
y5
# Out:
# array([6.250000e-02, 1.000000e+00, 5.062500e+00, 1.600000e+01,
#        3.906250e+01, 8.100000e+01, 1.500625e+02])

# %%
# All equations in the same plot

fig = plt.figure(figsize = (8.5,8.5))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y1, label = r"$\dot{\Theta}$(log n)")
ax.plot(x,y2, label = r"$\dot{\Theta}$(n)")
ax.plot(x,y3, label = r"$\dot{\Theta}$(n**2)")
ax.plot(x,y4, label = r"$\dot{\Theta}$(n**3)")
ax.plot(x,y5, label = r"$\dot{\Theta}$(n**k) where k = 4")
plt.legend(bbox_to_anchor= (1.05,1), loc='upper left', fontsize='x-large')

ax.set_title(r"$\dot{\Theta}$(log n) VS $\dot{\Theta}$(n) VS $\dot{\Theta}$(n**2) VS $\dot{\Theta}$(n**3) VS $\dot{\Theta}$(n**k) where k = 4", fontsize = 'xx-large')
ax.set_xlabel('X')
ax.set_ylabel('Time')
# Out:
# Text(0, 0.5, 'Time')
